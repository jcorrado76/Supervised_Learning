# %% [markdown]
# Standard imports

# %%
import deepchem as dc
import tensorflow as tf
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Load the data using the DeepChem module.
#
# The labels are binary, for compounds that either interact or don't interact with the androgen receptor.
#
# Note that these datasets are imbalanced because there are far fewer positive examples than there are negative examples.
#
# In addition, $w$ comes with recommended per-example weights in order to combat the imbalanced-ness of the dataset by giving more emphasis to positive examples.

# %%
_, (train, valid, test), _ = dc.molnet.load_tox21()
train_X, train_y, train_w = train.X, train.y, train.w
valid_X, valid_y, valid_w = valid.X, valid.y, valid.w
test_X, test_y, test_w = test.X, test.y, test.w
# Out:
# Loading dataset from disk.
# Loading dataset from disk.
# Loading dataset from disk.

# %% [markdown]
# Because Tox21 contains more datasets than we'll need, we can remove the labels associated with the extra datasets by selecting only the first columns of the label and weight arrays

# %%
train_y = train_y[:, 0]
valid_y = valid_y[:, 0]
test_y = test_y[:, 0]
train_w = train_w[:,0]
valid_w = valid_w[:, 0]
test_w = test_w[:, 0]

# %% [markdown]
# We will make use of the MoleculeNet dataset collection curated as part of DeepChem. Each molecule of Tox21 is processed into a bit-vector of length 1024 by DeepChem.
#
# We've used `None` to specify the number of rows for $x$ and $y$ to hold so that we can have indefinite numbers of rows in each of the mini-batches we will use to iterate over the dataset.
#
# To implement
#
# We use the matrix multiplication order $xW$ instead of $Wx$ in order to more conveniently deal with a mini-batch of input at a time. This is so that we can use whatever size $N$ we want for a single mini-batch.
#
# Then we apply the ReLU nonlinearity using the built-in `tf.nn.relu` activation function.
#
# Here, we build the entire computation graph

# %%
d = 1024
n_hidden = 50
learning_rate = .001
n_epochs = 10
batch_size = 100
dropout_prob = 0.5

# %%
with tf.name_scope("placeholders"):
    x = tf.placeholder( tf.float32, (None, d)) # indefinite number of rows
    y = tf.placeholder( tf.float32, (None,))   # indefinite number of rows that matches that of the above
#     keep_prob = tf.placeholder(tf.float32)
with tf.name_scope("hidden-layer"):
    W = tf.Variable( tf.random_normal((d, n_hidden)))
    b = tf.Variable( tf.random_normal((n_hidden, )))
    x_hidden = tf.nn.relu( tf.matmul(x, W) + b )
    # apply dropout
#     x_hidden = tf.nn.dropout( x_hidden, keep_prob )
with tf.name_scope("output"):
    W = tf.Variable(tf.random_normal((n_hidden,1)))
    b = tf.Variable(tf.random_normal((1,)))
    y_logit = tf.matmul(x_hidden, W) + b
    y_one_prob = tf.sigmoid(y_logit)
    y_pred = tf.round(y_one_prob)
with tf.name_scope("loss"):
    y_expand = tf.expand_dims(y,1)
    entropy = tf.nn.sigmoid_cross_entropy_with_logits(logits=y_logit, labels=y_expand)
    l = tf.reduce_sum(entropy)
    
with tf.name_scope("optim"):
    train_op = tf.train.AdamOptimizer(learning_rate).minimize(l)
    
with tf.name_scope("summaries"):
    tf.summary.scalar("loss",l)
    merged = tf.summary.merge_all()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0725 16:12:02.921087 140696018024256 deprecation.py:323] From /home/joseph/miniconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
train_writer = tf.summary.FileWriter('/tmp/fcnet-tox21',
                                     tf.get_default_graph())

# %% [markdown]
# Now we'll do the training part with mini-batching:
#
# We need to call `sess.run` for each mini-batch worth of data.

# %%
print(train_X.shape)
print(train_y.shape)
# Out:
# (6264, 1024)
# (6264,)

# %%
N = train_X.shape[0]
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    step = 0
    for epoch in range(n_epochs):
        pos = 0
        while pos < N:
            batch_X = train_X[pos:pos+batch_size]
            batch_y = train_y[pos:pos+batch_size]
            feed_dict = {x: batch_X, y: batch_y}
            _, summary, loss = sess.run([train_op, merged, l], feed_dict=feed_dict)
            print("epoch %d, step %d, loss: %f" % (epoch, step, loss))
            train_writer.add_summary(summary, step)

            step += 1
            pos += batch_size
    # Make Predictions
    valid_y_pred = sess.run(y_pred, feed_dict={x: valid_X})
# Out:
# epoch 0, step 0, loss: 465.333679
# epoch 0, step 1, loss: 550.427124
# epoch 0, step 2, loss: 732.376709
# epoch 0, step 3, loss: 534.642700
# epoch 0, step 4, loss: 591.761780
# epoch 0, step 5, loss: 538.295776
# epoch 0, step 6, loss: 552.799744
# epoch 0, step 7, loss: 398.739838
# epoch 0, step 8, loss: 461.339905
# epoch 0, step 9, loss: 387.447632
# epoch 0, step 10, loss: 620.415222
# epoch 0, step 11, loss: 664.459106
# epoch 0, step 12, loss: 316.986786
# epoch 0, step 13, loss: 410.047913
# epoch 0, step 14, loss: 389.063873
# epoch 0, step 15, loss: 435.414124
# epoch 0, step 16, loss: 334.097595
# epoch 0, step 17, loss: 433.203308
# epoch 0, step 18, loss: 406.787109
# epoch 0, step 19, loss: 381.007202
# epoch 0, step 20, loss: 479.168030
# epoch 0, step 21, loss: 265.992615
# epoch 0, step 22, loss: 366.928619
# epoch 0, step 23, loss: 295.207825
# epoch 0, step 24, loss: 331.018372
# epoch 0, step 25, loss: 392.106201
# epoch 0, step 26, loss: 313.021729
# epoch 0, step 27, loss: 388.259064
# epoch 0, step 28, loss: 239.099213
# epoch 0, step 29, loss: 179.259964
# epoch 0, step 30, loss: 283.242310
# epoch 0, step 31, loss: 237.865875
# epoch 0, step 32, loss: 218.919617
# epoch 0, step 33, loss: 415.788147
# epoch 0, step 34, loss: 288.937500
# epoch 0, step 35, loss: 323.350861
# epoch 0, step 36, loss: 207.253098
# epoch 0, step 37, loss: 246.033371
# epoch 0, step 38, loss: 224.317703
# epoch 0, step 39, loss: 347.377472
# epoch 0, step 40, loss: 251.025803
# epoch 0, step 41, loss: 339.921661
# epoch 0, step 42, loss: 207.340164
# epoch 0, step 43, loss: 140.791077
# epoch 0, step 44, loss: 278.124695
# epoch 0, step 45, loss: 289.823425
# epoch 0, step 46, loss: 241.403946
# epoch 0, step 47, loss: 341.605072
# epoch 0, step 48, loss: 271.684326
# epoch 0, step 49, loss: 135.522079
# epoch 0, step 50, loss: 219.822311
# epoch 0, step 51, loss: 254.514908
# epoch 0, step 52, loss: 257.970367
# epoch 0, step 53, loss: 217.141800
# epoch 0, step 54, loss: 144.964783
# epoch 0, step 55, loss: 254.638428
# epoch 0, step 56, loss: 233.421402
# epoch 0, step 57, loss: 214.492371
# epoch 0, step 58, loss: 353.812012
# epoch 0, step 59, loss: 129.867188
# epoch 0, step 60, loss: 348.674774
# epoch 0, step 61, loss: 143.686584
# epoch 0, step 62, loss: 186.143890
# epoch 1, step 63, loss: 59.250187
# epoch 1, step 64, loss: 145.617905
# epoch 1, step 65, loss: 172.802856
# epoch 1, step 66, loss: 212.405273
# epoch 1, step 67, loss: 252.326172
# epoch 1, step 68, loss: 222.399811
# epoch 1, step 69, loss: 254.336334
# epoch 1, step 70, loss: 105.605301
# epoch 1, step 71, loss: 176.147934
# epoch 1, step 72, loss: 184.423813
# epoch 1, step 73, loss: 239.905136
# epoch 1, step 74, loss: 267.334778
# epoch 1, step 75, loss: 164.817642
# epoch 1, step 76, loss: 235.694336
# epoch 1, step 77, loss: 253.509003
# epoch 1, step 78, loss: 194.790237
# epoch 1, step 79, loss: 222.017120
# epoch 1, step 80, loss: 212.400940
# epoch 1, step 81, loss: 295.199585
# epoch 1, step 82, loss: 106.179977
# epoch 1, step 83, loss: 232.123505
# epoch 1, step 84, loss: 93.878525
# epoch 1, step 85, loss: 200.808807
# epoch 1, step 86, loss: 140.974258
# epoch 1, step 87, loss: 186.986877
# epoch 1, step 88, loss: 229.873489
# epoch 1, step 89, loss: 89.864677
# epoch 1, step 90, loss: 220.794617
# epoch 1, step 91, loss: 144.777176
# epoch 1, step 92, loss: 28.269360
# epoch 1, step 93, loss: 144.141907
# epoch 1, step 94, loss: 127.674004
# epoch 1, step 95, loss: 111.551018
# epoch 1, step 96, loss: 200.265869
# epoch 1, step 97, loss: 192.126953
# epoch 1, step 98, loss: 160.234940
# epoch 1, step 99, loss: 108.407516
# epoch 1, step 100, loss: 111.384323
# epoch 1, step 101, loss: 138.491974
# epoch 1, step 102, loss: 210.583374
# epoch 1, step 103, loss: 137.807266
# epoch 1, step 104, loss: 220.311310
# epoch 1, step 105, loss: 111.062256
# epoch 1, step 106, loss: 90.563156
# epoch 1, step 107, loss: 206.412231
# epoch 1, step 108, loss: 147.738663
# epoch 1, step 109, loss: 112.061005
# epoch 1, step 110, loss: 206.779816
# epoch 1, step 111, loss: 166.489853
# epoch 1, step 112, loss: 101.522980
# epoch 1, step 113, loss: 135.630157
# epoch 1, step 114, loss: 148.626801
# epoch 1, step 115, loss: 168.855103
# epoch 1, step 116, loss: 109.292694
# epoch 1, step 117, loss: 95.293655
# epoch 1, step 118, loss: 145.606018
# epoch 1, step 119, loss: 154.571564
# epoch 1, step 120, loss: 154.303879
# epoch 1, step 121, loss: 323.454498
# epoch 1, step 122, loss: 112.624161
# epoch 1, step 123, loss: 250.211609
# epoch 1, step 124, loss: 104.519897
# epoch 1, step 125, loss: 149.714325
# epoch 2, step 126, loss: 26.472666
# epoch 2, step 127, loss: 98.557472
# epoch 2, step 128, loss: 91.686325
# epoch 2, step 129, loss: 177.948929
# epoch 2, step 130, loss: 206.418533
# epoch 2, step 131, loss: 195.035614
# epoch 2, step 132, loss: 175.858124
# epoch 2, step 133, loss: 74.249702
# epoch 2, step 134, loss: 126.340378
# epoch 2, step 135, loss: 126.612061
# epoch 2, step 136, loss: 176.935532
# epoch 2, step 137, loss: 179.089478
# epoch 2, step 138, loss: 126.101364
# epoch 2, step 139, loss: 206.605957
# epoch 2, step 140, loss: 229.733383
# epoch 2, step 141, loss: 126.943344
# epoch 2, step 142, loss: 158.610626
# epoch 2, step 143, loss: 166.312805
# epoch 2, step 144, loss: 275.768280
# epoch 2, step 145, loss: 75.347420
# epoch 2, step 146, loss: 155.830124
# epoch 2, step 147, loss: 64.903114
# epoch 2, step 148, loss: 168.842789
# epoch 2, step 149, loss: 103.326828
# epoch 2, step 150, loss: 132.843643
# epoch 2, step 151, loss: 175.393799
# epoch 2, step 152, loss: 56.420326
# epoch 2, step 153, loss: 168.148743
# epoch 2, step 154, loss: 93.874870
# epoch 2, step 155, loss: 15.974255
# epoch 2, step 156, loss: 118.792091
# epoch 2, step 157, loss: 89.775520
# epoch 2, step 158, loss: 88.901535
# epoch 2, step 159, loss: 130.108505
# epoch 2, step 160, loss: 159.798248
# epoch 2, step 161, loss: 133.140213
# epoch 2, step 162, loss: 93.186554
# epoch 2, step 163, loss: 82.333374
# epoch 2, step 164, loss: 94.888245
# epoch 2, step 165, loss: 138.256042
# epoch 2, step 166, loss: 79.920723
# epoch 2, step 167, loss: 172.785339
# epoch 2, step 168, loss: 83.208221
# epoch 2, step 169, loss: 78.887177
# epoch 2, step 170, loss: 178.637146
# epoch 2, step 171, loss: 112.295242
# epoch 2, step 172, loss: 69.710693
# epoch 2, step 173, loss: 158.035263
# epoch 2, step 174, loss: 118.097672
# epoch 2, step 175, loss: 81.516777
# epoch 2, step 176, loss: 94.986732
# epoch 2, step 177, loss: 74.909859
# epoch 2, step 178, loss: 118.276360
# epoch 2, step 179, loss: 52.260864
# epoch 2, step 180, loss: 70.994583
# epoch 2, step 181, loss: 101.348251
# epoch 2, step 182, loss: 99.536636
# epoch 2, step 183, loss: 115.422318
# epoch 2, step 184, loss: 291.349487
# epoch 2, step 185, loss: 107.937317
# epoch 2, step 186, loss: 202.547913
# epoch 2, step 187, loss: 85.309822
# epoch 2, step 188, loss: 121.179253
# epoch 3, step 189, loss: 15.638222
# epoch 3, step 190, loss: 71.976685
# epoch 3, step 191, loss: 64.575760
# epoch 3, step 192, loss: 153.714035
# epoch 3, step 193, loss: 185.422012
# epoch 3, step 194, loss: 183.333435
# epoch 3, step 195, loss: 129.996216
# epoch 3, step 196, loss: 62.455750
# epoch 3, step 197, loss: 89.183319
# epoch 3, step 198, loss: 106.130997
# epoch 3, step 199, loss: 149.522293
# epoch 3, step 200, loss: 126.126656
# epoch 3, step 201, loss: 99.462006
# epoch 3, step 202, loss: 186.226074
# epoch 3, step 203, loss: 201.984512
# epoch 3, step 204, loss: 90.439537
# epoch 3, step 205, loss: 106.014206
# epoch 3, step 206, loss: 140.455215
# epoch 3, step 207, loss: 253.849396
# epoch 3, step 208, loss: 66.533737
# epoch 3, step 209, loss: 115.367081
# epoch 3, step 210, loss: 55.541420
# epoch 3, step 211, loss: 152.162750
# epoch 3, step 212, loss: 70.741570
# epoch 3, step 213, loss: 99.378387
# epoch 3, step 214, loss: 138.721436
# epoch 3, step 215, loss: 41.722061
# epoch 3, step 216, loss: 137.062561
# epoch 3, step 217, loss: 57.399139
# epoch 3, step 218, loss: 11.714800
# epoch 3, step 219, loss: 108.941055
# epoch 3, step 220, loss: 64.836433
# epoch 3, step 221, loss: 77.506836
# epoch 3, step 222, loss: 96.104607
# epoch 3, step 223, loss: 133.109833
# epoch 3, step 224, loss: 121.833862
# epoch 3, step 225, loss: 84.035538
# epoch 3, step 226, loss: 66.819382
# epoch 3, step 227, loss: 73.056625
# epoch 3, step 228, loss: 91.536041
# epoch 3, step 229, loss: 45.483448
# epoch 3, step 230, loss: 142.864838
# epoch 3, step 231, loss: 67.166214
# epoch 3, step 232, loss: 72.584541
# epoch 3, step 233, loss: 158.717331
# epoch 3, step 234, loss: 96.468971
# epoch 3, step 235, loss: 49.007851
# epoch 3, step 236, loss: 136.545792
# epoch 3, step 237, loss: 93.779175
# epoch 3, step 238, loss: 67.525566
# epoch 3, step 239, loss: 71.395866
# epoch 3, step 240, loss: 48.374832
# epoch 3, step 241, loss: 83.574051
# epoch 3, step 242, loss: 28.565067
# epoch 3, step 243, loss: 64.592926
# epoch 3, step 244, loss: 76.061783
# epoch 3, step 245, loss: 67.637314
# epoch 3, step 246, loss: 87.431732
# epoch 3, step 247, loss: 260.883850
# epoch 3, step 248, loss: 105.046257
# epoch 3, step 249, loss: 171.662201
# epoch 3, step 250, loss: 69.805496
# epoch 3, step 251, loss: 100.209732
# epoch 4, step 252, loss: 10.694839
# epoch 4, step 253, loss: 51.636086
# epoch 4, step 254, loss: 51.075825
# epoch 4, step 255, loss: 137.131439
# epoch 4, step 256, loss: 168.768784
# epoch 4, step 257, loss: 176.651917
# epoch 4, step 258, loss: 97.034019
# epoch 4, step 259, loss: 56.121288
# epoch 4, step 260, loss: 65.213737
# epoch 4, step 261, loss: 104.311432
# epoch 4, step 262, loss: 133.579285
# epoch 4, step 263, loss: 101.272522
# epoch 4, step 264, loss: 79.795746
# epoch 4, step 265, loss: 166.654266
# epoch 4, step 266, loss: 177.122650
# epoch 4, step 267, loss: 67.156273
# epoch 4, step 268, loss: 74.364006
# epoch 4, step 269, loss: 137.096451
# epoch 4, step 270, loss: 234.714355
# epoch 4, step 271, loss: 60.245285
# epoch 4, step 272, loss: 98.633804
# epoch 4, step 273, loss: 48.436493
# epoch 4, step 274, loss: 138.755127
# epoch 4, step 275, loss: 48.128147
# epoch 4, step 276, loss: 84.072327
# epoch 4, step 277, loss: 111.532814
# epoch 4, step 278, loss: 32.943985
# epoch 4, step 279, loss: 120.043167
# epoch 4, step 280, loss: 30.499676
# epoch 4, step 281, loss: 8.453931
# epoch 4, step 282, loss: 100.617172
# epoch 4, step 283, loss: 49.332329
# epoch 4, step 284, loss: 70.466583
# epoch 4, step 285, loss: 80.866867
# epoch 4, step 286, loss: 114.534523
# epoch 4, step 287, loss: 113.094193
# epoch 4, step 288, loss: 78.391090
# epoch 4, step 289, loss: 54.005005
# epoch 4, step 290, loss: 58.873219
# epoch 4, step 291, loss: 62.219879
# epoch 4, step 292, loss: 31.465572
# epoch 4, step 293, loss: 122.236374
# epoch 4, step 294, loss: 56.417191
# epoch 4, step 295, loss: 67.881165
# epoch 4, step 296, loss: 141.090576
# epoch 4, step 297, loss: 85.825653
# epoch 4, step 298, loss: 40.377319
# epoch 4, step 299, loss: 120.533157
# epoch 4, step 300, loss: 76.869240
# epoch 4, step 301, loss: 56.661098
# epoch 4, step 302, loss: 56.665764
# epoch 4, step 303, loss: 34.433910
# epoch 4, step 304, loss: 60.621201
# epoch 4, step 305, loss: 20.058331
# epoch 4, step 306, loss: 62.130497
# epoch 4, step 307, loss: 63.053070
# epoch 4, step 308, loss: 46.856190
# epoch 4, step 309, loss: 68.490715
# epoch 4, step 310, loss: 241.175186
# epoch 4, step 311, loss: 99.088326
# epoch 4, step 312, loss: 154.709671
# epoch 4, step 313, loss: 63.159290
# epoch 4, step 314, loss: 85.327583
# epoch 5, step 315, loss: 8.783804
# epoch 5, step 316, loss: 38.013786
# epoch 5, step 317, loss: 39.928299
# epoch 5, step 318, loss: 123.612335
# epoch 5, step 319, loss: 151.934662
# epoch 5, step 320, loss: 166.823654
# epoch 5, step 321, loss: 75.671913
# epoch 5, step 322, loss: 51.770870
# epoch 5, step 323, loss: 54.823128
# epoch 5, step 324, loss: 103.624664
# epoch 5, step 325, loss: 120.919899
# epoch 5, step 326, loss: 85.489014
# epoch 5, step 327, loss: 66.516258
# epoch 5, step 328, loss: 150.206345
# epoch 5, step 329, loss: 157.386993
# epoch 5, step 330, loss: 52.604431
# epoch 5, step 331, loss: 52.455986
# epoch 5, step 332, loss: 132.374161
# epoch 5, step 333, loss: 216.061462
# epoch 5, step 334, loss: 55.508640
# epoch 5, step 335, loss: 90.507675
# epoch 5, step 336, loss: 41.752640
# epoch 5, step 337, loss: 127.587593
# epoch 5, step 338, loss: 40.857494
# epoch 5, step 339, loss: 76.580544
# epoch 5, step 340, loss: 92.615097
# epoch 5, step 341, loss: 26.936258
# epoch 5, step 342, loss: 107.984009
# epoch 5, step 343, loss: 17.065615
# epoch 5, step 344, loss: 5.589811
# epoch 5, step 345, loss: 93.187347
# epoch 5, step 346, loss: 38.641495
# epoch 5, step 347, loss: 68.607895
# epoch 5, step 348, loss: 75.449913
# epoch 5, step 349, loss: 105.680954
# epoch 5, step 350, loss: 103.845230
# epoch 5, step 351, loss: 73.592896
# epoch 5, step 352, loss: 43.377102
# epoch 5, step 353, loss: 48.661621
# epoch 5, step 354, loss: 45.650719
# epoch 5, step 355, loss: 23.244841
# epoch 5, step 356, loss: 105.235023
# epoch 5, step 357, loss: 48.177826
# epoch 5, step 358, loss: 63.162163
# epoch 5, step 359, loss: 123.773796
# epoch 5, step 360, loss: 76.628487
# epoch 5, step 361, loss: 34.207832
# epoch 5, step 362, loss: 104.889923
# epoch 5, step 363, loss: 63.301117
# epoch 5, step 364, loss: 49.622478
# epoch 5, step 365, loss: 46.549362
# epoch 5, step 366, loss: 25.908665
# epoch 5, step 367, loss: 50.023895
# epoch 5, step 368, loss: 14.145757
# epoch 5, step 369, loss: 59.491249
# epoch 5, step 370, loss: 51.919113
# epoch 5, step 371, loss: 30.650116
# epoch 5, step 372, loss: 59.286919
# epoch 5, step 373, loss: 223.775360
# epoch 5, step 374, loss: 93.591644
# epoch 5, step 375, loss: 142.253418
# epoch 5, step 376, loss: 58.423111
# epoch 5, step 377, loss: 73.508308
# epoch 6, step 378, loss: 7.431210
# epoch 6, step 379, loss: 29.140125
# epoch 6, step 380, loss: 31.912956
# epoch 6, step 381, loss: 110.446671
# epoch 6, step 382, loss: 137.123657
# epoch 6, step 383, loss: 156.071060
# epoch 6, step 384, loss: 61.034351
# epoch 6, step 385, loss: 47.665165
# epoch 6, step 386, loss: 47.290554
# epoch 6, step 387, loss: 100.399765
# epoch 6, step 388, loss: 109.395775
# epoch 6, step 389, loss: 75.626923
# epoch 6, step 390, loss: 56.071827
# epoch 6, step 391, loss: 133.922546
# epoch 6, step 392, loss: 139.368561
# epoch 6, step 393, loss: 42.255390
# epoch 6, step 394, loss: 39.302795
# epoch 6, step 395, loss: 125.977097
# epoch 6, step 396, loss: 196.679230
# epoch 6, step 397, loss: 51.684639
# epoch 6, step 398, loss: 85.035973
# epoch 6, step 399, loss: 36.311813
# epoch 6, step 400, loss: 118.457596
# epoch 6, step 401, loss: 37.747910
# epoch 6, step 402, loss: 70.039566
# epoch 6, step 403, loss: 78.221153
# epoch 6, step 404, loss: 23.365007
# epoch 6, step 405, loss: 100.254662
# epoch 6, step 406, loss: 11.367652
# epoch 6, step 407, loss: 3.714682
# epoch 6, step 408, loss: 86.398346
# epoch 6, step 409, loss: 29.781878
# epoch 6, step 410, loss: 67.412865
# epoch 6, step 411, loss: 71.824066
# epoch 6, step 412, loss: 97.227554
# epoch 6, step 413, loss: 95.317009
# epoch 6, step 414, loss: 69.151962
# epoch 6, step 415, loss: 35.064056
# epoch 6, step 416, loss: 40.001629
# epoch 6, step 417, loss: 35.193115
# epoch 6, step 418, loss: 17.929106
# epoch 6, step 419, loss: 90.025047
# epoch 6, step 420, loss: 41.261284
# epoch 6, step 421, loss: 58.508560
# epoch 6, step 422, loss: 106.538345
# epoch 6, step 423, loss: 69.145790
# epoch 6, step 424, loss: 30.020016
# epoch 6, step 425, loss: 92.678314
# epoch 6, step 426, loss: 50.991573
# epoch 6, step 427, loss: 45.357525
# epoch 6, step 428, loss: 38.240730
# epoch 6, step 429, loss: 19.840885
# epoch 6, step 430, loss: 43.786285
# epoch 6, step 431, loss: 10.188231
# epoch 6, step 432, loss: 55.731617
# epoch 6, step 433, loss: 42.278839
# epoch 6, step 434, loss: 18.240072
# epoch 6, step 435, loss: 52.620884
# epoch 6, step 436, loss: 206.932663
# epoch 6, step 437, loss: 88.365829
# epoch 6, step 438, loss: 130.796234
# epoch 6, step 439, loss: 54.040379
# epoch 6, step 440, loss: 65.629250
# epoch 7, step 441, loss: 6.123206
# epoch 7, step 442, loss: 22.779453
# epoch 7, step 443, loss: 25.941908
# epoch 7, step 444, loss: 98.106094
# epoch 7, step 445, loss: 126.399811
# epoch 7, step 446, loss: 145.341461
# epoch 7, step 447, loss: 50.258404
# epoch 7, step 448, loss: 43.671402
# epoch 7, step 449, loss: 40.724903
# epoch 7, step 450, loss: 95.125397
# epoch 7, step 451, loss: 99.035583
# epoch 7, step 452, loss: 66.749161
# epoch 7, step 453, loss: 48.171501
# epoch 7, step 454, loss: 118.736755
# epoch 7, step 455, loss: 125.514603
# epoch 7, step 456, loss: 34.641323
# epoch 7, step 457, loss: 30.273224
# epoch 7, step 458, loss: 118.441071
# epoch 7, step 459, loss: 179.300140
# epoch 7, step 460, loss: 48.295017
# epoch 7, step 461, loss: 79.760620
# epoch 7, step 462, loss: 31.205069
# epoch 7, step 463, loss: 110.707687
# epoch 7, step 464, loss: 35.287277
# epoch 7, step 465, loss: 64.527206
# epoch 7, step 466, loss: 67.072090
# epoch 7, step 467, loss: 20.790073
# epoch 7, step 468, loss: 93.770546
# epoch 7, step 469, loss: 8.632127
# epoch 7, step 470, loss: 2.822533
# epoch 7, step 471, loss: 79.865723
# epoch 7, step 472, loss: 25.130638
# epoch 7, step 473, loss: 65.221153
# epoch 7, step 474, loss: 68.767555
# epoch 7, step 475, loss: 89.031509
# epoch 7, step 476, loss: 87.201828
# epoch 7, step 477, loss: 64.993843
# epoch 7, step 478, loss: 27.021326
# epoch 7, step 479, loss: 34.777130
# epoch 7, step 480, loss: 28.662939
# epoch 7, step 481, loss: 15.911655
# epoch 7, step 482, loss: 77.615959
# epoch 7, step 483, loss: 35.487213
# epoch 7, step 484, loss: 54.030800
# epoch 7, step 485, loss: 92.449547
# epoch 7, step 486, loss: 62.482449
# epoch 7, step 487, loss: 26.105446
# epoch 7, step 488, loss: 84.616203
# epoch 7, step 489, loss: 40.818062
# epoch 7, step 490, loss: 41.639034
# epoch 7, step 491, loss: 31.303171
# epoch 7, step 492, loss: 16.107513
# epoch 7, step 493, loss: 40.257523
# epoch 7, step 494, loss: 7.168288
# epoch 7, step 495, loss: 51.849518
# epoch 7, step 496, loss: 34.809265
# epoch 7, step 497, loss: 11.077578
# epoch 7, step 498, loss: 47.410999
# epoch 7, step 499, loss: 190.971649
# epoch 7, step 500, loss: 83.303085
# epoch 7, step 501, loss: 120.162445
# epoch 7, step 502, loss: 50.159286
# epoch 7, step 503, loss: 63.377087
# epoch 8, step 504, loss: 4.884189
# epoch 8, step 505, loss: 17.922279
# epoch 8, step 506, loss: 21.515381
# epoch 8, step 507, loss: 86.758476
# epoch 8, step 508, loss: 117.856796
# epoch 8, step 509, loss: 135.427582
# epoch 8, step 510, loss: 42.019623
# epoch 8, step 511, loss: 39.861877
# epoch 8, step 512, loss: 36.025208
# epoch 8, step 513, loss: 88.110184
# epoch 8, step 514, loss: 89.409103
# epoch 8, step 515, loss: 58.499126
# epoch 8, step 516, loss: 41.354362
# epoch 8, step 517, loss: 105.648102
# epoch 8, step 518, loss: 116.583359
# epoch 8, step 519, loss: 29.259830
# epoch 8, step 520, loss: 24.914564
# epoch 8, step 521, loss: 110.241150
# epoch 8, step 522, loss: 163.026978
# epoch 8, step 523, loss: 45.305954
# epoch 8, step 524, loss: 74.546104
# epoch 8, step 525, loss: 26.629887
# epoch 8, step 526, loss: 104.126190
# epoch 8, step 527, loss: 32.981976
# epoch 8, step 528, loss: 60.001205
# epoch 8, step 529, loss: 58.292938
# epoch 8, step 530, loss: 18.782053
# epoch 8, step 531, loss: 87.909309
# epoch 8, step 532, loss: 6.646454
# epoch 8, step 533, loss: 2.443455
# epoch 8, step 534, loss: 73.498199
# epoch 8, step 535, loss: 23.250750
# epoch 8, step 536, loss: 61.573528
# epoch 8, step 537, loss: 65.866859
# epoch 8, step 538, loss: 80.911781
# epoch 8, step 539, loss: 79.534958
# epoch 8, step 540, loss: 61.181343
# epoch 8, step 541, loss: 19.668812
# epoch 8, step 542, loss: 31.278614
# epoch 8, step 543, loss: 24.308588
# epoch 8, step 544, loss: 14.422380
# epoch 8, step 545, loss: 67.511429
# epoch 8, step 546, loss: 30.979746
# epoch 8, step 547, loss: 49.790390
# epoch 8, step 548, loss: 80.401909
# epoch 8, step 549, loss: 56.790249
# epoch 8, step 550, loss: 22.678446
# epoch 8, step 551, loss: 77.598366
# epoch 8, step 552, loss: 34.111710
# epoch 8, step 553, loss: 38.137848
# epoch 8, step 554, loss: 25.630234
# epoch 8, step 555, loss: 13.743765
# epoch 8, step 556, loss: 37.636665
# epoch 8, step 557, loss: 5.045681
# epoch 8, step 558, loss: 48.569439
# epoch 8, step 559, loss: 29.346813
# epoch 8, step 560, loss: 7.540020
# epoch 8, step 561, loss: 43.483696
# epoch 8, step 562, loss: 175.512802
# epoch 8, step 563, loss: 78.331345
# epoch 8, step 564, loss: 109.767166
# epoch 8, step 565, loss: 46.595047
# epoch 8, step 566, loss: 61.815533
# epoch 9, step 567, loss: 3.640553
# epoch 9, step 568, loss: 14.323296
# epoch 9, step 569, loss: 18.342236
# epoch 9, step 570, loss: 76.152466
# epoch 9, step 571, loss: 110.376976
# epoch 9, step 572, loss: 125.627983
# epoch 9, step 573, loss: 34.876869
# epoch 9, step 574, loss: 36.409691
# epoch 9, step 575, loss: 33.134140
# epoch 9, step 576, loss: 80.712395
# epoch 9, step 577, loss: 81.653130
# epoch 9, step 578, loss: 51.218266
# epoch 9, step 579, loss: 35.158909
# epoch 9, step 580, loss: 94.563339
# epoch 9, step 581, loss: 108.219391
# epoch 9, step 582, loss: 26.557547
# epoch 9, step 583, loss: 21.198139
# epoch 9, step 584, loss: 101.901283
# epoch 9, step 585, loss: 147.682541
# epoch 9, step 586, loss: 42.691589
# epoch 9, step 587, loss: 69.365410
# epoch 9, step 588, loss: 22.713120
# epoch 9, step 589, loss: 98.143440
# epoch 9, step 590, loss: 30.743660
# epoch 9, step 591, loss: 56.322128
# epoch 9, step 592, loss: 51.024750
# epoch 9, step 593, loss: 17.364742
# epoch 9, step 594, loss: 81.905228
# epoch 9, step 595, loss: 5.248399
# epoch 9, step 596, loss: 2.290516
# epoch 9, step 597, loss: 67.235825
# epoch 9, step 598, loss: 22.141272
# epoch 9, step 599, loss: 57.025673
# epoch 9, step 600, loss: 62.588566
# epoch 9, step 601, loss: 72.895515
# epoch 9, step 602, loss: 72.526619
# epoch 9, step 603, loss: 57.809929
# epoch 9, step 604, loss: 13.156654
# epoch 9, step 605, loss: 28.168564
# epoch 9, step 606, loss: 20.567825
# epoch 9, step 607, loss: 13.340635
# epoch 9, step 608, loss: 59.098835
# epoch 9, step 609, loss: 27.072498
# epoch 9, step 610, loss: 45.641064
# epoch 9, step 611, loss: 70.701553
# epoch 9, step 612, loss: 51.648922
# epoch 9, step 613, loss: 20.121429
# epoch 9, step 614, loss: 70.900879
# epoch 9, step 615, loss: 28.200277
# epoch 9, step 616, loss: 34.803341
# epoch 9, step 617, loss: 20.738823
# epoch 9, step 618, loss: 12.059649
# epoch 9, step 619, loss: 35.400139
# epoch 9, step 620, loss: 3.461730
# epoch 9, step 621, loss: 45.533573
# epoch 9, step 622, loss: 24.831509
# epoch 9, step 623, loss: 6.140911
# epoch 9, step 624, loss: 40.385403
# epoch 9, step 625, loss: 160.958893
# epoch 9, step 626, loss: 73.433540
# epoch 9, step 627, loss: 99.825539
# epoch 9, step 628, loss: 43.147667
# epoch 9, step 629, loss: 60.208355

# %% [markdown]
# Now we can score our predictions to see what our accuracy is.
#
# Because we are doing binary classification, and we have imbalanced datasets, in real life, you should do a full classification analysis with recall and precision and the confusion matrix, etc.

# %%
score = accuracy_score(valid_y, valid_y_pred)
print("Unweighted Classification Accuracy: %f" % score)

weighted_score = accuracy_score(valid_y, valid_y_pred, sample_weight=valid_w)
print("Weighted Classification Accuracy: %f" % weighted_score)
# Out:
# Unweighted Classification Accuracy: 0.931034
# Weighted Classification Accuracy: 0.644231

# %% [markdown]
# We can see that we get a high unweighted classification accuracy and a low weighted classification accuracy, which is a problematic sign. We know we have imbalanced datasets.

# %%
train_y_series = pd.Series(train_y)

# %%
train_y_series.value_counts()
# Out:
# 0.0    6023
# 1.0     241
# dtype: int64

# %% [markdown]
# Here, we see we have significantly more instances of class 0 than that of class 1.
#
# This means that if we were to make a model that simply guessed always 0, we would get a 96% accuracy. This is very misleading, and illustrates the reason as to why we cannot judge our model based solely on accuracy.
#
# You can view the results with:
#
# ```bash
# tensorboard --logdir /tmp/fcnet-tox21&
# ```
